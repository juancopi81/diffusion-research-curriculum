# %% [markdown]
# # Week {{WEEK}} — {{TITLE}}
#
# **Mode**: experiment
# **Companion note**: `notes/w{{WEEK_PAD}}_{{TOPIC_SLUG}}.md`
# {{PAIR_ROLE}}
#
# ## Learning Objectives
# 1. Turn this week's concept into a concrete experiment.
# 2. Keep every step reproducible and easy to rerun.
# 3. Summarize findings with short, testable observations.

# %% [markdown]
# ---
#
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed={{SEED}})
plt.rcParams["figure.figsize"] = (9, 5)
plt.rcParams["font.size"] = 12

# %%
config = {
    "week": {{WEEK}},
    "topic": "{{TOPIC_SLUG}}",
    "seed": {{SEED}},
}
config

# %% [markdown]
# ---
#
# ## Section 1: Core Computation
#
# ### {{WORK_PREFIX}} 1.1: Implement the key equation or update rule

# %%
# {{WORK_PREFIX}}: implement the minimal computation for this section.
# Example placeholders:
# x = ...
# y = ...
# result = ...

# %% [markdown]
# ### {{WORK_PREFIX}} 1.2: Verify numerically

# %%
# {{WORK_PREFIX}}: add a small numerical verification.
# CHECKPOINT: include at least one lightweight assertion.
# assert ...

# %% [markdown]
# ---
#
# ## Section 2: Visualization
#
# ### {{WORK_PREFIX}} 2.1: Create one clear diagnostic plot

# %%
# {{WORK_PREFIX}}: produce one plot that supports the key claim.
# x = ...
# y = ...
# plt.plot(x, y)
# plt.title("...")
# plt.show()

# %% [markdown]
# ---
#
# ## Section 3: Ablation or Parameter Sweep
#
# ### {{WORK_PREFIX}} 3.1: Compare a small set of settings

# %%
# {{WORK_PREFIX}}: run a small sweep and store concise metrics.
# settings = [...]
# metrics = {}
# for value in settings:
#     metrics[value] = ...
# metrics

# %% [markdown]
# ---
#
# ## Observations
#
# - Main result:
# - Evidence (metric/plot):
# - Limitation or open question:

# %% [markdown]
# ---
#
# ## Done
#
# {{DONE_NOTE}}
