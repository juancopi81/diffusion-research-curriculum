# %% [markdown]
# # Week {{WEEK}} — {{TITLE}}
#
# **Mode**: tutorial
# **Companion note**: `notes/w{{WEEK_PAD}}_{{TOPIC_SLUG}}.md`
# {{PAIR_ROLE}}
#
# ## Learning Goals
# 1. Understand the core intuition for this week's concept.
# 2. Reproduce each step with short runnable code cells.
# 3. Complete one exercise that checks understanding.

# %% [markdown]
# ## Outline
#
# 1. Setup
# 2. Step 1: Minimal example
# 3. Step 2: Interpretation
# 4. Exercise
# 5. Wrap-up

# %% [markdown]
# ---
#
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed={{SEED}})
plt.rcParams["figure.figsize"] = (9, 5)
plt.rcParams["font.size"] = 12

# %% [markdown]
# ---
#
# ## Step 1: Minimal Example
#
# ### {{WORK_PREFIX}} 1.1: Build the smallest runnable example

# %%
# {{WORK_PREFIX}}: write the smallest possible working example.
# Keep it focused on one concept.

# %% [markdown]
# ---
#
# ## Step 2: Interpret the Result
#
# ### {{WORK_PREFIX}} 2.1: Add one diagnostic plot or metric

# %%
# {{WORK_PREFIX}}: add one plot or metric that makes the concept tangible.
# CHECKPOINT: include a lightweight assertion.
# assert ...

# %% [markdown]
# ---
#
# ## Exercise
#
# ### {{WORK_PREFIX}} 3.1: Solve a short exercise

# %%
# {{WORK_PREFIX}}: implement the exercise solution here.
# Prompt: adapt Step 1 to a slightly different setting and compare outcomes.

# %% [markdown]
# ---
#
# ## Wrap-up
#
# - Key takeaway:
# - Common pitfall:
# - Optional extension:
#
# {{DONE_NOTE}}
